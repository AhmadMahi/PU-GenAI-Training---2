# %%
from openai import OpenAI
from google.colab import userdata

# Get API key from Colab Secrets
client = OpenAI(
    api_key=userdata.get("OPENAI_API_KEY")
)

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "I Am Ahmed , Here in Chennai"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello Ahmed! How are you doing today? If there's anything specific you'd like to talk about or any questions you have, feel free to let me know!

# %%
# role_prompt = [
#     {"role": "system", "content": "You are a senior cloud security architect reviewing designs for enterprise clients. Be direct and flag risks explicitly."},
#     {"role": "user", "content": "We're storing user API keys in plaintext in a Postgres table. Thoughts?"},
# ]

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "What's Football"
        },
         {
             "role": "system",
             "content": "You Are Teacher CEO , So ALways Speak in That Same Tone "
          }
    ]
)

print(response.choices[0].message.content)
# Out:
# Football, often referred to as soccer in certain regions, is a globally beloved team sport that epitomizes athleticism, strategy, and teamwork. Played on a rectangular field with a goal at each end, the objective is to score by getting the ball into the opposing team's goal.
#
# Let’s break down some key aspects of the game:
#
# 1. **Rules and Structure**: Governed by a set of laws known as the Laws of the Game, football involves two teams, each consisting of 11 players. Matches are played in two halves of 45 minutes each, with a 15-minute half-time break.
#
# 2. **Positions and Roles**: Players are assigned specific positions, including forwards, midfielders, defenders, and a goalkeeper, each with distinct responsibilities that contribute to the team's overall strategy.
#
# 3. **Skills and Techniques**: Mastery of fundamental skills such as dribbling, passing, and shooting is essential for individual and team success. Players often engage in rigorous training to enhance their abilities.
#
# 4. **Global Appeal**: Football boasts a vast following and is an integral part of many cultures. Major tournaments, such as the FIFA World Cup and continental championships, capture worldwide attention and celebrate national pride.
#
# 5. **Development and Education**: At its core, football promotes values such as teamwork, discipline, and resilience. Many educational institutions incorporate the sport into their curricula, recognizing its role in physical and social development.
#
# In summary, football is not just a game; it is a powerful vehicle for community engagement and personal growth. It nurtures talents and teaches life lessons, making it invaluable in the realms of education and personal development. Thank you for your attention to this overview. If there are specific areas of interest, I encourage further discussion.

# %%
conversation = {
    "messages": []
}

# %%
from openai import OpenAI
from google.colab import userdata

# Get API key from Colab Secrets
client = OpenAI(api_key=userdata.get("OPENAI_API_KEY"))

# Store conversation history
# conversation = {
#     "messages": []
# }

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        break

    # Add user's message to conversation
    conversation["messages"].append({
        "role": "user",
        "content": user_input
    })

    # Send entire conversation to OpenAI
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=conversation["messages"],
        temperature=0.7,
        max_tokens=250
    )

    # Extract AI response
    assistant_response = response.choices[0].message.content

    # Add AI response to conversation
    conversation["messages"].append({
        "role": "assistant",
        "content": assistant_response
    })

    print("AI:", assistant_response)
    print("-" * 50)

print("\nConversation History:")
print(conversation)
# Out:
# You: What Is My NAme
# AI: You mentioned earlier that your name is John. If there's anything else you'd like to share or ask, feel free!
# --------------------------------------------------
# You: What Did We Speak Earlier
# AI: Earlier, you introduced yourself as John and mentioned that you are from Pune. You also asked about the meaning of "PC" in different contexts, including personal computers and the program counter in CPUs. If there's anything specific you'd like to revisit or discuss further, let me know!
# --------------------------------------------------
# You: exit
#
# Conversation History:
# {'messages': [{'role': 'user', 'content': "What's My NAme"}, {'role': 'assistant', 'content': 'It seems like you might be referencing the song "What\'s My Name?" by Rihanna featuring Drake. If you meant something else or have a different question in mind, please let me know!'}, {'role': 'user', 'content': 'Hi My Name is John And i Am Fromp Pune'}, {'role': 'assistant', 'content': "Hi John! Nice to meet you. How's everything in Pune?"}, {'role': 'user', 'content': 'Tell me What Is PC'}, {'role': 'assistant', 'content': '"PC" typically stands for "personal computer." It refers to a versatile computer designed for individual use, which can perform a variety of tasks such as word processing, internet browsing, gaming, and more. PCs can come in different forms, including desktops, laptops, and tablets.\n\nIn addition to "personal computer," "PC" can also refer to other contexts, such as:\n\n1. **Political Correctness:** A social and political term that refers to language, policies, or measures intended to avoid offense or disadvantage to members of particular groups in society.\n\n2. **Player Character:** In gaming, this refers to a character controlled by a player rather than by the game itself.\n\nIf you meant something else by "PC," please let me know!'}, {'role': 'user', 'content': 'And What Abput PC In CPU'}, {'role': 'assistant', 'content': 'In the context of a CPU (Central Processing Unit), "PC" stands for **Program Counter**. The Program Counter is a special register in the CPU that keeps track of the address of the next instruction that needs to be executed in a program. \n\n### Key Points about the Program Counter (PC):\n\n1. **Instruction Tracking:** The PC increments its value after each instruction is fetched, allowing the CPU to know where to find the next instruction to execute.\n\n2. **Branching:** If a program includes a jump or branch instruction (like a loop or conditional statement), the PC can be updated to point to a different memory address, enabling the CPU to execute instructions out of the normal sequential order.\n\n3. **Functionality:** The PC is vital for the control flow of programs, ensuring that the CPU executes instructions in the correct sequence.\n\nIn summary, the Program Counter is an essential component of the CPU that plays a crucial role in the execution of programs by keeping track of instruction addresses.'}, {'role': 'user', 'content': 'What Is My NAme'}, {'role': 'assistant', 'content': "You mentioned earlier that your name is John. If there's anything else you'd like to share or ask, feel free!"}, {'role': 'user', 'content': 'What Did We Speak Earlier'}, {'role': 'assistant', 'content': 'Earlier, you introduced yourself as John and mentioned that you are from Pune. You also asked about the meaning of "PC" in different contexts, including personal computers and the program counter in CPUs. If there\'s anything specific you\'d like to revisit or discuss further, let me know!'}]}

# %%
# Cnoversation Summary Memory
from openai import OpenAI
from google.colab import userdata

client = OpenAI(api_key=userdata.get("OPENAI_API_KEY"))

# Store only a summary instead of the complete conversation
conversation_summary = ""

while True:

    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        break

    # Create the prompt using only the summary + latest question
    messages = [
        {
            "role": "system",
            "content": """
            You are a helpful conversational AI.
            Use the conversation summary to maintain context.
            Answer the user's latest question clearly and concisely.
            """
        },
        {
            "role": "user",
            "content": f"""
            Previous Conversation Summary:
            {conversation_summary}

            New User Question:
            {user_input}
            """
        }
    ]

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
        temperature=0.7
    )

    assistant_response = response.choices[0].message.content

    print("\nAI:", assistant_response)

    # Display token usage
    usage = response.usage

    print("\n--- Token Usage ---")
    print("Input Tokens:", usage.prompt_tokens)
    print("Output Tokens:", usage.completion_tokens)
    print("Total Tokens:", usage.total_tokens)

    # Update the conversation summary
    summary_response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": """
                Summarize the conversation in simple, crisp language.
                Keep only information that is useful for maintaining
                future conversational context.
                Do not include unnecessary details.
                """
            },
            {
                "role": "user",
                "content": f"""
                Existing Summary:
                {conversation_summary}

                New User Question:
                {user_input}

                AI Response:
                {assistant_response}
                """
            }
        ],
        temperature=0
    )

    conversation_summary = summary_response.choices[0].message.content

    print("\n--- Current Summary ---")
    print(conversation_summary)
    print("=" * 60)
# Out:
# You: Hi
#
# AI: Hello! How can I assist you today?
#
# --- Token Usage ---
# Input Tokens: 58
# Output Tokens: 9
# Total Tokens: 67
#
# --- Current Summary ---
# User greeted the AI. AI responded and offered assistance.
# ============================================================
# You: What is Wifi
#
# AI: Wi-Fi is a technology that allows electronic devices to connect to a wireless local area network (WLAN), typically using radio waves. It enables devices like smartphones, laptops, and tablets to access the internet and communicate with each other without the need for physical cables.
#
# --- Token Usage ---
# Input Tokens: 71
# Output Tokens: 52
# Total Tokens: 123
#
# --- Current Summary ---
# User asked about Wi-Fi. AI explained that Wi-Fi is a technology for connecting devices to a wireless local area network (WLAN) using radio waves, allowing internet access and communication without cables.
# ============================================================
# You: And What Is Lifi
#
# AI: Li-Fi (Light Fidelity) is a wireless communication technology that uses light to transmit data. Unlike Wi-Fi, which uses radio waves, Li-Fi utilizes visible, ultraviolet, and infrared light to send information. This allows for high-speed data transmission and can be used in environments where radio frequency communication is not suitable, such as in hospitals or aircraft.
#
# --- Token Usage ---
# Input Tokens: 101
# Output Tokens: 69
# Total Tokens: 170
#
# --- Current Summary ---
# User inquired about Li-Fi. AI explained that Li-Fi (Light Fidelity) is a wireless communication technology that uses light to transmit data, offering high-speed transmission and suitable for environments where radio waves are not ideal.
# ============================================================
# You: What Did We Speak So Far
#
# AI: We discussed Li-Fi, which is a wireless communication technology that uses light to transmit data. It offers high-speed transmission and is suitable for environments where radio waves may not be ideal.
#
# --- Token Usage ---
# Input Tokens: 106
# Output Tokens: 36
# Total Tokens: 142
#
# --- Current Summary ---
# User asked about Li-Fi, and AI explained it as a wireless communication technology using light for data transmission, providing high speed and being suitable for areas where radio waves are not effective.
# ============================================================
# You: exit

# %%
# Store Only the Last N Conversations
from openai import OpenAI
from google.colab import userdata

client = OpenAI(api_key=userdata.get("OPENAI_API_KEY"))

conversation = []

MAX_TURNS = 3

while True:

    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        break

    # Add user message
    conversation.append({
        "role": "user",
        "content": user_input
    })

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=conversation,
        temperature=0.7
    )

    assistant_response = response.choices[0].message.content

    # Add AI response
    conversation.append({
        "role": "assistant",
        "content": assistant_response
    })

    print("\nAI:", assistant_response)

    # Token information
    print("\n--- Token Usage ---")
    print("Input Tokens:", response.usage.prompt_tokens)
    print("Output Tokens:", response.usage.completion_tokens)
    print("Total Tokens:", response.usage.total_tokens)

    # Keep only the latest N turns
    conversation = conversation[-(MAX_TURNS * 2):]

    print("\n--- Stored Messages ---")
    print(len(conversation))

    print("=" * 60)
# Out:
# You: exit
